# %%
import pandas as pd
import numpy as np

# %%
guns_15 = pd.read_csv("Resources/2015_all_gun_deaths.csv")
guns_16 = pd.read_csv("Resources/2016_all_gun_deaths.csv")
guns_17 = pd.read_csv("Resources/2017_all_gun_deaths.csv")

# %%
guns_17.head()
# Out:
#    Unnamed: 0  Resident_Status Education  Month_Of_Death Sex  Age_Key  \
# 0          60                1                       101   F        1
# 1          86                1                       101   M        1
# 2         112                1                       101   M        1
# 3         162                1                       101   F        1
# 4         179                1                       101   M        1
#
#    Age_Value Age_Sub_Flag  Age_Recode_52  Age_Recode_27  ...  RA18 RA19  RA20  \
# 0         34                          32             12  ...
# 1         16                          29              9  ...
# 2         31                          32             12  ...
# 3         21                          30             10  ...
# 4         17                          29              9  ...
#
#   Race  Race_Bridged  Race_Imputation Race_Recode_3 Race_Recode_5  \
# 0    3                                            2             3
# ...
